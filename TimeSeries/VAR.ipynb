# %% [markdown]
# # VAR
# https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/

# %% [markdown]
# ## 1 - Data Prep

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
root = "../"
path = root + 'CSV/TabNet/Internacoes/'
all_files = glob.glob(path + "*")
df_diseases = pd.DataFrame()
list_of_diseases = []
for file in all_files:
    file_name = file.split("\\")[1]
    disease = file_name.split(".")[0]
    list_of_diseases.append(disease)
    df_disease = pd.read_csv(path + file_name, sep=";")
    df_disease = df_disease[df_disease["Município"] == "355030 São Paulo"]
    if not df_disease.empty:
        df_disease= df_disease.filter(regex='2008|2009|2010|2011|2012|2013|2014|2015|2016|2017|2018', axis=1)
        df_disease = df_disease.transpose()
        df_disease.columns = [disease]
        df_disease = df_disease.replace("-",0)
        df_disease = df_disease.astype(int)
        df_diseases[disease] = df_disease[disease]
df_diseases = df_diseases.fillna(0)

# %%
from datetime import datetime
month_dic = {
    "Jan": "January",
    "Fev": "February",
    "Mar": "March",
    "Abr": "April",
    "Mai": "May",
    "Jun": "June",
    "Jul": "July",
    "Ago": "August",
    "Set": "September",
    "Out": "October",
    "Nov": "November",
    "Dez": "December"
}
indexes = []
for i,e in enumerate(df_diseases.index): 
    ano = e.split("/")[0]
    mes = e.split("/")[1]
    month = month_dic[mes]
    datetime_object = datetime.strptime(month, "%B")
    indexes.append(str(datetime_object.month) + "/" + str(ano))
df_diseases.index = indexes
df_diseases.head()
# Out:
#         ABORTO_ESPONTÂNEO  ABORTO_POR_RAZÕES_MÉDICAS  ACIDENTES_DE_TRANSPORTE  \
# 1/2008                497                         18                      1.0
# 2/2008                452                          6                      0.0
# 3/2008                503                         16                      0.0
# 4/2008                471                         11                      1.0
# 5/2008                453                          9                      0.0
#
#         ACID_VASCULAR_CEREBR_ISQUÊM_TRANSIT_E_SÍNDR_CORREL  \
# 1/2008                                                 50
# 2/2008                                                 31
# 3/2008                                                 41
# 4/2008                                                 34
# 5/2008                                                 49
#
#         ACID_VASCULAR_CEREBR_NÃO_ESPEC_HEMORRÁG_OU_ISQUÊM  \
# 1/2008                                                429
# 2/2008                                                410
# 3/2008                                                361
# 4/2008                                                375
# 5/2008                                                397
#
#         AFECÇ_HEMORRÁG_E_OUTR_DOENÇ_SANG_E_ÓRG_HEMATOPOÉT  \
# 1/2008                                                 72
# 2/2008                                                 84
# 3/2008                                                103
# 4/2008                                                104
# 5/2008                                                 81
#
#         AFOGAMENTO_E_SUBMERSÃO_ACIDENTAMENTE  AGRESSÕES  \
# 1/2008                                   0.0        0.0
# 2/2008                                   0.0        2.0
# 3/2008                                   0.0        0.0
# 4/2008                                   2.0        0.0
# 5/2008                                   1.0        1.0
#
#         ALGUNS_TRANSTORNOS_ENVOLVENDO_MECANISMO_IMUNITÁRIO  AMEBÍASE  ...  \
# 1/2008                                                  5          0  ...
# 2/2008                                                  7          1  ...
# 3/2008                                                  6          3  ...
# 4/2008                                                  2          5  ...
# 5/2008                                                  0          1  ...
#
#         TUBERCULOSE_DO_APARELHO_GENITURINÁRIO  TUBERCULOSE_DO_SISTEMA_NERVOSO  \
# 1/2008                                    0.0                               0
# 2/2008                                    0.0                               0
# 3/2008                                    0.0                               3
# 4/2008                                    0.0                               2
# 5/2008                                    0.0                               0
#
#         TUBERCULOSE_MILIAR  TUBERCULOSE_PULMONAR  \
# 1/2008                   1                   168
# 2/2008                   1                    36
# 3/2008                   1                    14
# 4/2008                   1                    18
# 5/2008                   1                    17
#
#         TUBERCULOSE_ÓSSEA_E_DAS_ARTICULAÇÕES  \
# 1/2008                                     0
# 2/2008                                     0
# 3/2008                                     1
# 4/2008                                     1
# 5/2008                                     0
#
#         TUBERC_INTEST_PERITÔNIO_GLÂNGL_MESENTÉRICOS  UROLITÍASE  \
# 1/2008                                          0.0         121
# 2/2008                                          0.0         148
# 3/2008                                          0.0         137
# 4/2008                                          0.0         135
# 5/2008                                          0.0         155
#
#         VARICELA_E_HERPES_ZOSTER  VEIAS_VARICOSAS_DAS_EXTREMIDADES_INFERIORES  \
# 1/2008                        21                                          230
# 2/2008                         4                                          278
# 3/2008                         8                                          304
# 4/2008                        10                                          274
# 5/2008                         9                                          260
#
#         ÚLCERA_GÁSTRICA_E_DUODENAL
# 1/2008                          62
# 2/2008                          61
# 3/2008                          55
# 4/2008                          66
# 5/2008                          85
#
# [5 rows x 337 columns]

# %%
path = root + 'CSV/TabNet/Suicides/'
all_files = glob.glob(path + "*")
df_suicides = pd.DataFrame()
list_of_years = []
for file in all_files:
    file_name = file.split("\\")[1]
    year = file_name.split("_")[1].split(".")[0]
    list_of_years.append(year)
    df_year = pd.read_csv(path + file_name, sep=";")
    df_year = df_year.replace("-",0)
    df_year = df_year[df_year["Município"] == "355030 São Paulo"]
    df_year = df_year.drop(columns=["Município", "Total"])
    if not df_year.empty:
        df_year = df_year.transpose()
        df_year.columns = ["SUICIDE"]
        df_year = df_year.astype(int)
        df_year.index = df_year.index + "/" + year
        df_suicides = pd.concat([df_suicides, df_year])

# %%
from datetime import datetime
month_dic = {
    "Janeiro": "January",
    "Fevereiro": "February",
    "Março": "March",
    "Abril": "April",
    "Maio": "May",
    "Junho": "June",
    "Julho": "July",
    "Agosto": "August",
    "Setembro": "September",
    "Outubro": "October",
    "Novembro": "November",
    "Dezembro": "December"
}
indexes = []
for i,e in enumerate(df_suicides.index): 
    mes = e.split("/")[0]
    ano = e.split("/")[1]
    month = month_dic[mes]
    datetime_object = datetime.strptime(month, "%B")
    indexes.append(str(datetime_object.month) + "/" + str(ano))
df_suicides.index = indexes
df_suicides.head()
# Out:
#         SUICIDE
# 1/2008       43
# 2/2008       42
# 3/2008       50
# 4/2008       46
# 5/2008       38

# %% [markdown]
# For now we will only use some of the diseases' data

# %%
df = df_diseases.copy()
df["SUICIDE"] = df_suicides["SUICIDE"]
chosen = ["TRANSTORNOS_DE_HUMOR_[AFETIVOS]", "TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL", "NEOPLASIA_MALIGNA_DO_CÓLON", "NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL", "BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC", "SUICIDE"]
df = df[chosen]
df.head()
# Out:
#         TRANSTORNOS_DE_HUMOR_[AFETIVOS]  \
# 1/2008                              485
# 2/2008                              271
# 3/2008                              298
# 4/2008                              300
# 5/2008                              325
#
#         TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL  \
# 1/2008                                                314
# 2/2008                                                213
# 3/2008                                                202
# 4/2008                                                257
# 5/2008                                                267
#
#         NEOPLASIA_MALIGNA_DO_CÓLON  \
# 1/2008                          99
# 2/2008                          78
# 3/2008                          95
# 4/2008                          88
# 5/2008                         119
#
#         NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL  \
# 1/2008                                                 68
# 2/2008                                                 87
# 3/2008                                                 84
# 4/2008                                                 84
# 5/2008                                                 98
#
#         BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC  SUICIDE
# 1/2008                                                185       43
# 2/2008                                                217       42
# 3/2008                                                228       50
# 4/2008                                                234       46
# 5/2008                                                239       38

# %% [markdown]
# ## 2 - Visualization

# %% [markdown]
# Visualizing the time series

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ## 3 - Granger’s causality
# Granger’s causality tests the null hypothesis that the coefficients of past values in the regression equation is zero.
# So, if the p-value obtained from the test is lesser than the significance level of 0.05, then, you can safely reject the null hypothesis.

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(df, variables = df.columns)
# Out:
#                                                     TRANSTORNOS_DE_HUMOR_[AFETIVOS]_x  \
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                                              1.0000
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...                             0.0021
# NEOPLASIA_MALIGNA_DO_CÓLON_y                                                   0.0007
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...                             0.0157
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...                             0.0603
# SUICIDE_y                                                                      0.0001
#
#                                                     TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL_x  \
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                                                              0.0034
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...                                             1.0000
# NEOPLASIA_MALIGNA_DO_CÓLON_y                                                                   0.4263
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...                                             0.0043
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...                                             0.0466
# SUICIDE_y                                                                                      0.0013
#
#                                                     NEOPLASIA_MALIGNA_DO_CÓLON_x  \
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                                         0.0001
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...                        0.0001
# NEOPLASIA_MALIGNA_DO_CÓLON_y                                              1.0000
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...                        0.0166
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...                        0.0151
# SUICIDE_y                                                                 0.0063
#
#                                                     NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL_x  \
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                                                              0.0000
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...                                             0.0161
# NEOPLASIA_MALIGNA_DO_CÓLON_y                                                                   0.0001
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...                                             1.0000
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...                                             0.0002
# SUICIDE_y                                                                                      0.0003
#
#                                                     BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC_x  \
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                                                              0.0003
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...                                             0.0108
# NEOPLASIA_MALIGNA_DO_CÓLON_y                                                                   0.0809
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...                                             0.3259
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...                                             1.0000
# SUICIDE_y                                                                                      0.0080
#
#                                                     SUICIDE_x
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]_y                      0.0143
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLC...     0.0052
# NEOPLASIA_MALIGNA_DO_CÓLON_y                           0.0740
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_AN...     0.0217
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔN...     0.0020
# SUICIDE_y                                              1.0000

# %% [markdown]
# The row are the Response (Y) and the columns are the predictor series (X).
#
# If a given p-value is < significance level (0.05), then, the corresponding X series (column) causes the Y (row).
#
# - TRANSTORNOS_DE_HUMOR -> suicide? Yes

# %% [markdown]
# ## 4 - Cointegration Test
# Cointegration test helps to establish the presence of a statistically significant connection between two or more time series.
#
# ### Order of integration
# It is the number of differencing required to make a non-stationary time series stationary.
#
# When you have two or more time series, and there exists a linear combination of them that has an order of integration (d) less than that of the individual series, then the collection of series is said to be **cointegrated**.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(df)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# TRANSTORNOS_DE_HUMOR_[AFETIVOS] ::  68.2      > 83.9383   =>   False
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL ::  34.7      > 60.0627   =>   False
# NEOPLASIA_MALIGNA_DO_CÓLON ::  18.72     > 40.1749   =>   False
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL ::  9.56      > 24.2761   =>   False
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC ::  3.57      > 12.3212   =>   False
# SUICIDE ::  0.7       > 4.1296    =>   False

# %% [markdown]
# ## 5 - Split into train and test

# %%
nobs = 4
df_train, df_test = df[0:-nobs], df[-nobs:]

# Check size
print(df_train.shape)
print(df_test.shape)
# Out:
# (128, 6)
# (4, 6)

# %% [markdown]
# ## 6 - Stationarity
# A stationary time series is one whose characteristics like mean and variance does not change over time.
#
# ### Augmented Dickey-Fuller Test (ADF Test)

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
for name, column in df_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "TRANSTORNOS_DE_HUMOR_[AFETIVOS]"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.7894
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.486
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.8222. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.7499
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.8334. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "NEOPLASIA_MALIGNA_DO_CÓLON"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.4324
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.1328. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6225
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.487
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.4714. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8819
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.488
#  Critical value 5%     = -2.887
#  Critical value 10%    = -2.58
#  => P-Value = 0.3406. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SUICIDE"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.0882
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.485
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.7198. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
df_differenced = df_train.diff().dropna()

# %% [markdown]
# Re-running to check for stationarity

# %%
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "TRANSTORNOS_DE_HUMOR_[AFETIVOS]"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.634
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.486
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.4045
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "NEOPLASIA_MALIGNA_DO_CÓLON"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.3467
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.484
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3678
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.487
#  Critical value 5%     = -2.886
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.5173
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.488
#  Critical value 5%     = -2.887
#  Critical value 10%    = -2.58
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "SUICIDE"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.0838
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.485
#  Critical value 5%     = -2.885
#  Critical value 10%    = -2.579
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ## 7 - Order (p) of VAR model
#
# To select the right order of the VAR model, we iteratively fit increasing orders of VAR model and pick the order that gives a model with least AIC.

# %%
model = VAR(df_differenced)
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# Lag Order = 1
# AIC :  36.17696443967702
# BIC :  37.122391741994186
# FPE :  5149374179567146.0
# HQIC:  36.56106192265558
#
# Lag Order = 2
# AIC :  35.89566425351931
# BIC :  37.66053202559595
# FPE :  3901717113617402.0
# HQIC:  36.61263686394535
#
# Lag Order = 3
# AIC :  35.91328931543113
# BIC :  38.50612881929383
# FPE :  4011274108781888.5
# HQIC:  36.96656168704559
#
# Lag Order = 4
# AIC :  36.00608226328982
# BIC :  39.435575379597644
# FPE :  4489540009335183.0
# HQIC:  37.39913374857967
#
# Lag Order = 5
# AIC :  35.9853586067399
# BIC :  40.26034151100536
# FPE :  4548840535898761.0
# HQIC:  37.721724360627185
#
# Lag Order = 6
# AIC :  35.98132653381956
# BIC :  41.11079348524498
# FPE :  4776929883706972.0
# HQIC:  38.06459861800744
#
# Lag Order = 7
# AIC :  36.12877310424727
# BIC :  42.121880351228675
# FPE :  5987448629374566.0
# HQIC:  38.56260161221533
#
# Lag Order = 8
# AIC :  36.048720197589134
# BIC :  42.91479000409997
# FPE :  6181616187012893.0
# HQIC:  38.83681440017508
#
# Lag Order = 9
# AIC :  36.05618817665917
# BIC :  43.80471297389366
# FPE :  7280013025346269.0
# HQIC:  39.202317688102305
# C:\Users\pypas\anaconda3\envs\ML\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# Let's go with Lag Order = 2
#
# Another way of choosing:

# %%
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## 8 - Train the model

# %%
model_fitted = model.fit(2)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 02, Sep, 2020
# Time:                     19:03:57
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    37.6605
# Nobs:                     125.000    HQIC:                   36.6126
# Log likelihood:          -3229.68    FPE:                3.90172e+15
# AIC:                      35.8957    Det(Omega_mle):     2.15497e+15
# --------------------------------------------------------------------
# Results for equation TRANSTORNOS_DE_HUMOR_[AFETIVOS]
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                        -1.361612         2.522153           -0.540           0.589
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                           -0.370595         0.089655           -4.134           0.000
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.139930         0.113426           -1.234           0.217
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.483592         0.142565           -3.392           0.001
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.153320         0.167594            0.915           0.360
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.023675         0.070553           -0.336           0.737
# L1.SUICIDE                                                   -0.222074         0.330887           -0.671           0.502
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                           -0.271853         0.079629           -3.414           0.001
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.055515         0.111265           -0.499           0.618
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                 0.067248         0.151292            0.444           0.657
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.113515         0.166526            0.682           0.495
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.026582         0.069827           -0.381           0.703
# L2.SUICIDE                                                   -0.384918         0.317856           -1.211           0.226
# ========================================================================================================================
#
# Results for equation TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                        -1.032165         2.076170           -0.497           0.619
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.067766         0.073802            0.918           0.359
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.645682         0.093369           -6.915           0.000
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.331624         0.117356           -2.826           0.005
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.041300         0.137959            0.299           0.765
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.007285         0.058077           -0.125           0.900
# L1.SUICIDE                                                    0.309877         0.272377            1.138           0.255
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.077286         0.065548            1.179           0.238
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.279669         0.091591           -3.053           0.002
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.080487         0.124540           -0.646           0.518
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL         -0.052117         0.137080           -0.380           0.704
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC          0.046132         0.057480            0.803           0.422
# L2.SUICIDE                                                    0.190481         0.261651            0.728           0.467
# ========================================================================================================================
#
# Results for equation NEOPLASIA_MALIGNA_DO_CÓLON
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                         0.957044         1.673919            0.572           0.567
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                           -0.122225         0.059503           -2.054           0.040
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL         0.003337         0.075279            0.044           0.965
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.598977         0.094618           -6.330           0.000
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.059496         0.111230            0.535           0.593
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC          0.025492         0.046825            0.544           0.586
# L1.SUICIDE                                                    0.086713         0.219605            0.395           0.693
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.051498         0.052849            0.974           0.330
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.044875         0.073845           -0.608           0.543
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.424614         0.100411           -4.229           0.000
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.038413         0.110521            0.348           0.728
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC          0.076324         0.046343            1.647           0.100
# L2.SUICIDE                                                   -0.329338         0.210957           -1.561           0.118
# ========================================================================================================================
#
# Results for equation NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                         1.052687         1.449537            0.726           0.468
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.065051         0.051527            1.262           0.207
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.092495         0.065188           -1.419           0.156
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.124039         0.081935           -1.514           0.130
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL         -0.497544         0.096320           -5.166           0.000
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.008185         0.040548           -0.202           0.840
# L1.SUICIDE                                                    0.111349         0.190168            0.586           0.558
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.053525         0.045765            1.170           0.242
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.152512         0.063947           -2.385           0.017
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.039297         0.086951           -0.452           0.651
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL         -0.210913         0.095706           -2.204           0.028
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC          0.023420         0.040131            0.584           0.559
# L2.SUICIDE                                                   -0.014323         0.182679           -0.078           0.938
# ========================================================================================================================
#
# Results for equation BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                         0.234595         3.358314            0.070           0.944
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                           -0.050214         0.119378           -0.421           0.674
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.282904         0.151030           -1.873           0.061
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.087427         0.189829           -0.461           0.645
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.469765         0.223155            2.105           0.035
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.335721         0.093943           -3.574           0.000
# L1.SUICIDE                                                    0.137744         0.440585            0.313           0.755
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.042600         0.106028            0.402           0.688
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.315886         0.148153           -2.132           0.033
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.135470         0.201450           -0.672           0.501
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.684484         0.221733            3.087           0.002
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.210229         0.092976           -2.261           0.024
# L2.SUICIDE                                                   -0.123688         0.423234           -0.292           0.770
# ========================================================================================================================
#
# Results for equation SUICIDE
# ========================================================================================================================
#                                                            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------
# const                                                        -0.369530         0.703090           -0.526           0.599
# L1.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                           -0.006586         0.024993           -0.264           0.792
# L1.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.049483         0.031619           -1.565           0.118
# L1.NEOPLASIA_MALIGNA_DO_CÓLON                                -0.026899         0.039742           -0.677           0.499
# L1.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL         -0.024457         0.046719           -0.523           0.601
# L1.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.034497         0.019668           -1.754           0.079
# L1.SUICIDE                                                   -0.362337         0.092240           -3.928           0.000
# L2.TRANSTORNOS_DE_HUMOR_[AFETIVOS]                            0.043037         0.022198            1.939           0.053
# L2.TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL        -0.043877         0.031017           -1.415           0.157
# L2.NEOPLASIA_MALIGNA_DO_CÓLON                                 0.000113         0.042175            0.003           0.998
# L2.NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL          0.105313         0.046422            2.269           0.023
# L2.BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC         -0.035460         0.019465           -1.822           0.069
# L2.SUICIDE                                                   -0.185575         0.088607           -2.094           0.036
# ========================================================================================================================
#
# Correlation matrix of residuals
#                                                       TRANSTORNOS_DE_HUMOR_[AFETIVOS]  TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL  NEOPLASIA_MALIGNA_DO_CÓLON  NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL  BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC   SUICIDE
# TRANSTORNOS_DE_HUMOR_[AFETIVOS]                                              1.000000                                            0.093876                    0.191281                                           0.084063                                           0.119986 -0.008813
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL                           0.093876                                            1.000000                   -0.072392                                           0.048765                                          -0.063899  0.262160
# NEOPLASIA_MALIGNA_DO_CÓLON                                                   0.191281                                           -0.072392                    1.000000                                           0.324596                                           0.222704  0.083762
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL                            0.084063                                            0.048765                    0.324596                                           1.000000                                           0.250170  0.034975
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC                            0.119986                                           -0.063899                    0.222704                                           0.250170                                           1.000000  0.070692
# SUICIDE                                                                     -0.008813                                            0.262160                    0.083762                                           0.034975                                           0.070692  1.000000

# %% [markdown]
# ## 9 - Serial Correlation of Residuals
# If there is any correlation left in the residuals, then, there is some pattern in the time series that is still left to be explained by the model. In that case, the typical course of action is to either increase the order of the model or induce more predictors into the system or look for a different algorithm to model the time series.
#
# ### Durbin Watson’s Statistic
# The value of this statistic can vary between 0 and 4.
# - The closer it is to the value 2, then there is no significant serial correlation.
# - The closer to 0, there is a positive serial correlation
# - The closer it is to 4 implies negative serial correlation.

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_fitted.resid)
def adjust(val, length= 6): return str(val).ljust(length)
for col, val in zip(df.columns, out):
    print(adjust(col), ':', round(val, 2))
# Out:
# TRANSTORNOS_DE_HUMOR_[AFETIVOS] : 2.27
# TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL : 2.06
# NEOPLASIA_MALIGNA_DO_CÓLON : 2.05
# NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL : 2.07
# BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC : 2.1
# SUICIDE : 2.16

# %% [markdown]
# ## 10 - Forecast

# %%
lag_order = model_fitted.k_ar
print(lag_order)  #> 2
forecast_input = df_differenced.values[-lag_order:]
forecast_input
# Out:
# 2
# array([[-16.,  14.,   0.,  22., -54.,  -2.],
#        [ -1.,  -3.,  46.,  11., -10.,   2.]])

# %% [markdown]
# Forecasting

# %%
fc = model_fitted.forecast(y=forecast_input, steps=nobs)
df_forecast = pd.DataFrame(fc, index=df.index[-nobs:], columns=df.columns + '_1d')
df_forecast
# Out:
#          TRANSTORNOS_DE_HUMOR_[AFETIVOS]_1d  \
# 9/2018                           -13.062269
# 10/2018                           21.644770
# 11/2018                          -10.944156
# 12/2018                           -8.173722
#
#          TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL_1d  \
# 9/2018                                          -22.441316
# 10/2018                                          18.329081
# 11/2018                                          -0.072529
# 12/2018                                         -11.293491
#
#          NEOPLASIA_MALIGNA_DO_CÓLON_1d  \
# 9/2018                      -29.980643
# 10/2018                      -0.307193
# 11/2018                      13.344782
# 12/2018                      -6.159972
#
#          NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL_1d  \
# 9/2018                                          -18.476791
# 10/2018                                          11.112635
# 11/2018                                           3.946224
# 12/2018                                          -7.852060
#
#          BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC_1d  SUICIDE_1d
# 9/2018                                           27.466388       1.199383
# 10/2018                                          -3.817585       1.938901
# 11/2018                                          -7.217471      -4.976673
# 12/2018                                           6.572285       2.376002

# %% [markdown]
# The forecasts are generated but it is on the scale of the training data used by the model. So, to bring it back up to its original scale, you need to de-difference it as many times you had differenced the original input data.

# %% [markdown]
# ## 11 - Invert the transformation

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(df_train, df_forecast, second_diff=False)
forecast_array = []
for i in chosen:
    forecast_array.append(i + "_forecast")
df_results.loc[:, forecast_array]
# Out:
#          TRANSTORNOS_DE_HUMOR_[AFETIVOS]_forecast  \
# 9/2018                                 216.937731
# 10/2018                                238.582501
# 11/2018                                227.638345
# 12/2018                                219.464623
#
#          TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL_forecast  \
# 9/2018                                          105.558684
# 10/2018                                         123.887766
# 11/2018                                         123.815237
# 12/2018                                         112.521746
#
#          NEOPLASIA_MALIGNA_DO_CÓLON_forecast  \
# 9/2018                            160.019357
# 10/2018                           159.712165
# 11/2018                           173.056947
# 12/2018                           166.896974
#
#          NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL_forecast  \
# 9/2018                                          156.523209
# 10/2018                                         167.635844
# 11/2018                                         171.582069
# 12/2018                                         163.730009
#
#          BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC_forecast  \
# 9/2018                                          353.466388
# 10/2018                                         349.648803
# 11/2018                                         342.431332
# 12/2018                                         349.003617
#
#          SUICIDE_forecast
# 9/2018          16.199383
# 10/2018         18.138284
# 11/2018         13.161612
# 12/2018         15.537613

# %% [markdown]
# ## 12 - Plotting the results

# %%
fig, axes = plt.subplots(nrows=int(len(df.columns)/2), ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    df_test[col][-nobs:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ## 13 - Evaluating forecast

# %%
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

for i in chosen:
    print('Forecast Accuracy of: ' + i)
    accuracy_prod = forecast_accuracy(df_results[i + '_forecast'].values, df_test[i])
    for k, v in accuracy_prod.items():
        print(adjust(k), ': ', round(v,4))
    print("\n")
# Out:
# Forecast Accuracy of: TRANSTORNOS_DE_HUMOR_[AFETIVOS]
# mape   :  0.072
# me     :  -17.5942
# mae    :  17.5942
# mpe    :  -0.072
# rmse   :  18.4924
# corr   :  0.8102
# minmax :  0.072
#
#
# Forecast Accuracy of: TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁLCOOL
# mape   :  0.1382
# me     :  -18.5541
# mae    :  18.5541
# mpe    :  -0.1382
# rmse   :  18.8226
# corr   :  0.9403
# minmax :  0.1382
#
#
# Forecast Accuracy of: NEOPLASIA_MALIGNA_DO_CÓLON
# mape   :  0.1441
# me     :  20.6714
# mae    :  20.6714
# mpe    :  0.1441
# rmse   :  21.2501
# corr   :  0.5957
# minmax :  0.125
#
#
# Forecast Accuracy of: NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL
# mape   :  0.096
# me     :  7.8678
# mae    :  14.5499
# mpe    :  0.0591
# rmse   :  17.0754
# corr   :  0.2261
# minmax :  0.0858
#
#
# Forecast Accuracy of: BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC
# mape   :  0.1225
# me     :  33.1375
# mae    :  36.4219
# mpe    :  0.1131
# rmse   :  44.0317
# corr   :  -0.8688
# minmax :  0.1037
#
#
# Forecast Accuracy of: SUICIDE
# mape   :  0.1201
# me     :  -2.4908
# mae    :  2.5716
# mpe    :  -0.1139
# rmse   :  3.4928
# corr   :  0.8913
# minmax :  0.1201
