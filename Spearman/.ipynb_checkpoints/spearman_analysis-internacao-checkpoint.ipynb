# %% [markdown]
# # Spearman Correlation
# The idea is to analyse the correlation between the disease rates and suicide rates in each municipality.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import glob
from scipy.stats import spearmanr
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

root = "../"

# %% [markdown]
# Read suicide csv

# %%
suicide = pd.read_csv(root + 'CSV/Suicide/suicide_rates_08_18.csv', sep=',', index_col=0)
suicide.head()
# Out:
#    MUNCOD    RATE_08    RATE_09    RATE_10   RATE_11    RATE_12    RATE_13  \
# 0  110001  20.344224   8.212203   8.189337  4.127456  12.464166   7.773632
# 1  110002   9.458389   2.338060   4.427031  4.368243   9.703818   1.974938
# 2  110003   0.000000  14.936520   0.000000  0.000000   0.000000  15.396459
# 3  110004   5.110972   7.626311   2.544497  1.266480   5.042229   1.164646
# 4  110005   0.000000   0.000000  11.743981  0.000000  11.868028   0.000000
#
#     RATE_14    RATE_15    RATE_16    RATE_17    RATE_18
# 0  3.898332  11.728829   7.841292  11.793844   4.316485
# 1  4.860976   4.789226   5.665936   9.315758   1.883807
# 2  0.000000  31.471282  15.900779   0.000000  18.389114
# 3  5.776607   6.878683  10.241588   5.649271   9.432516
# 4  0.000000  11.119760  11.136478   5.576001   6.081245

# %% [markdown]
# Rates for SP

# %%
suicide[suicide["MUNCOD"] == 355030]
# Out:
#       MUNCOD   RATE_08   RATE_09   RATE_10   RATE_11   RATE_12   RATE_13  \
# 3685  355030  4.549487  4.683992  4.722364  4.763117  4.931138  4.593181
#
#        RATE_14   RATE_15   RATE_16   RATE_17   RATE_18
# 3685  4.488944  4.411829  3.164932  3.559948  1.741006

# %%
disease = ""
path = root + "CSV/TabNet/Internacoes_Rate/"
all_files = glob.glob(path + "*.csv")

years = ["08", "09", "10", "11", "12", "13", "14", "15", "16", "17", "18"]
suicide_df = suicide.copy()
suicide_df["SUICIDE"] = suicide_df.drop(columns="MUNCOD").sum(axis=1)/(len(suicide_df.columns) - 1)
suicide_df = suicide_df[["MUNCOD", "SUICIDE"]]

diseases_list = []
corrs_list = []
p_value_list = []
size_list = []

for file in all_files:
    file_name = file.split("\\")[1]
    disease = file_name.split(".csv")[0]
    disease_df = pd.read_csv(path + disease + '.csv', sep=',', index_col=0) 
    disease_df["Total"] = disease_df.drop(columns="MUNCOD").sum(axis=1)/(len(disease_df.columns) - 1)
    disease_df = disease_df[["MUNCOD", "Total"]]
    disease_df = disease_df[(disease_df["Total"] != 0)] # Excluded rows with 0 suicides
    if disease_df.shape[0] > 2500:
        final_df = pd.merge(disease_df, suicide_df, on="MUNCOD")
        size_list.append(final_df.shape[0])
        corr, p_value = spearmanr(final_df["Total"],final_df["SUICIDE"])
        diseases_list.append(disease)
        corrs_list.append(corr)
        p_value_list.append(p_value)

# %%
corrs_data = {'Doenças': diseases_list, 'Correlação com suicidio': corrs_list, 'P value': p_value_list, "Qtd Municipios": size_list}
corrs_df = pd.DataFrame(data=corrs_data)
corrs_df.sort_values(by=['Correlação com suicidio'], ascending=False).reset_index(drop=True).head(50)
# Out:
#                                               Doenças  \
# 0                     TRANSTORNOS_DE_HUMOR_[AFETIVOS]
# 1   TRANST_MENTAIS_E_COMPORTAMENTAIS_DEV_USO_DE_ÁL...
# 2                          NEOPLASIA_MALIGNA_DO_CÓLON
# 3   NEOPLASIA_MALIGNA_DE_TRAQUÉIA_BRÔNQUIOS_E_PULMÕES
# 4   TRANST_MENTAIS_COMPORT_DEV_USO_OUTR_SUBST_PSICOAT
# 5   BRONQUITE_ENFISEMA_E_OUTR_DOENÇ_PULM_OBSTR_CRÔNIC
# 6   NEOPL_MALIG_JUNÇÃO_RETOSSIGM_RETO_ÂNUS_CANAL_ANAL
# 7                  OUTRAS_NEOPLASIAS_MALIGNAS_DA_PELE
# 8       TRANSTORNOS_DE_CONDUÇÃO_E_ARRITMIAS_CARDÍACAS
# 9     FLEBITE_TROMBOFLEBITE_EMBOLIA_E_TROMBOSE_VENOSA
# 10               OUTRAS_DOENÇAS_ISQUÊMICAS_DO_CORAÇÃO
# 11    TRANSTORNOS_DOS_NERVOS_RAÍZES_E_PLEXOS_NERVOSOS
# 12  NEOPL_MALIG_OUTR_LOCALIZ_MAL_DEF_SECUN_E_NÃO_E...
# 13                                DOENÇAS_DO_APÊNDICE
# 14                          COLELITÍASE_E_COLECISTITE
# 15                       NEOPLASIA_MALIGNA_DO_ESÔFAGO
# 16                     OUTROS_TRANSTRONOS_ARTICULARES
# 17                                         UROLITÍASE
# 18     PANCREATITE_AGUDA_E_OUTRAS_DOENÇAS_DO_PÂNCREAS
# 19     TRANSTORNOS_DA_DENSIDADE_E_DA_ESTRUTURA_ÓSSEAS
# 20                  OUTRAS_DOENÇAS_DO_SISTEMA_NERVOSO
# 21  OUTRAS_DOENÇAS_SIST_OSTEOMUSCULAR_E_TEC_CONJUN...
# 22                       EMBOLIA_E_TROMBOSE_ARTERIAIS
# 23                         TRANSTORNOS_DO_TECIDO_MOLE
# 24                      NEOPLASIA_MALIGNA_DO_ESTÔMAGO
# 25     DOENÇAS_CRÔNICAS_DAS_AMÍGDALAS_E_DAS_ADENÓIDES
# 26        VEIAS_VARICOSAS_DAS_EXTREMIDADES_INFERIORES
# 27  ILEO_PARALÍTICO_E_OBSTRUÇÃO_INTESTINAL_SEM_HÉRNIA
# 28                         INFARTO_AGUDO_DO_MIOCÁRDIO
# 29  ACID_VASCULAR_CEREBR_ISQUÊM_TRANSIT_E_SÍNDR_CO...
# 30                          NEOPLASIA_MALIGNA_DA_MAMA
# 31                             INSUFICIÊNCIA_CARDÍACA
# 32                                   FRATURA_DO_FÊMUR
# 33                  FRATURA_DO_PESCOÇO_TÓRAX_OU_PELVE
# 34                         ÚLCERA_GÁSTRICA_E_DUODENAL
# 35  NEOPLASIA_MALIGNA_DO_LÁBIO_CAVIDADE_ORAL_E_FAR...
# 36  AFECÇ_HEMORRÁG_E_OUTR_DOENÇ_SANG_E_ÓRG_HEMATOPOÉT
# 37  OUTR_NEOPL_IN_SITU_BENIGS_E_COMPORT_INCERT_DES...
# 38  CERT_COMPL_PREC_TRAUM_COMPL_CIRÚRG_ASS_MÉDIC_NCOP
# 39                                INSUFICIÊNCIA_RENAL
# 40                          OUTRAS_DOENÇAS_DO_CORAÇÃO
# 41   NEOPL_MALIG_DO_TECIDO_MESOTELIAL_E_TECIDOS_MOLES
# 42                         DOENÇA_ALCOÓLICA_DO_FÍGADO
# 43                           HEMORRAGIA_INTRACRANIANA
# 44                DOENÇAS_RENAIS_TÚBULO-INTERSTICIAIS
# 45  LESÕES_ESMAG_AMPUT_TRAUMÁT_REG_ESP_E_MÚLTIP_CORPO
# 46                                         SEPTICEMIA
# 47                 NEOPLASIA_MALIGNA_DO_COLO_DO_ÚTERO
# 48  LUXAÇÕES_ENTORSE_DISTENSÃO_REG_ESP_E_MÚLTIP_CORPO
# 49                                     OUTRAS_ANEMIAS
#
#     Correlação com suicidio        P value  Qtd Municipios
# 0                  0.434420  1.360525e-154            3357
# 1                  0.397686  6.620686e-131            3445
# 2                  0.372220  2.342180e-105            3189
# 3                  0.371460   5.702495e-89            2696
# 4                  0.369459   1.201612e-90            2780
# 5                  0.368975  9.287829e-156            4833
# 6                  0.352598   9.779801e-86            2903
# 7                  0.352155   8.054332e-95            3226
# 8                  0.346575  2.839456e-120            4252
# 9                  0.344610   4.838143e-99            3532
# 10                 0.344398  5.285582e-133            4773
# 11                 0.336089   3.475875e-72            2696
# 12                 0.322378   8.423039e-96            3933
# 13                 0.315682  2.218468e-116            5012
# 14                 0.306869  5.897759e-116            5300
# 15                 0.305881   1.067013e-61            2799
# 16                 0.304582   5.387990e-81            3734
# 17                 0.297144   1.354036e-89            4360
# 18                 0.285257   1.076889e-61            3239
# 19                 0.283557   1.061907e-50            2678
# 20                 0.283175   1.369465e-74            3997
# 21                 0.282989   2.287009e-49            2616
# 22                 0.282037   1.282846e-48            2593
# 23                 0.281260   3.295764e-63            3420
# 24                 0.279892   2.625528e-57            3123
# 25                 0.271329   3.491177e-59            3444
# 26                 0.270380   1.495242e-67            3975
# 27                 0.260658   4.541412e-62            3931
# 28                 0.260420   1.818897e-72            4618
# 29                 0.257263   1.063608e-43            2809
# 30                 0.255365   7.633246e-59            3882
# 31                 0.254544   3.175706e-78            5236
# 32                 0.253879   1.466726e-72            4874
# 33                 0.246594   1.022285e-39            2775
# 34                 0.242147   5.873973e-37            2672
# 35                 0.240041   5.315181e-44            3264
# 36                 0.239408   3.036519e-36            2680
# 37                 0.236584   7.020242e-60            4627
# 38                 0.232775   3.867656e-56            4476
# 39                 0.231735   9.837585e-59            4733
# 40                 0.229789   1.995788e-43            3522
# 41                 0.229000   1.938585e-35            2868
# 42                 0.224120   2.883702e-32            2716
# 43                 0.223821   2.104735e-40            3448
# 44                 0.222777   3.060928e-53            4637
# 45                 0.220120   2.215185e-35            3105
# 46                 0.218407   8.957181e-50            4504
# 47                 0.216705   2.200055e-32            2921
# 48                 0.214703   4.211079e-47            4405
# 49                 0.210783   3.459904e-46            4482
